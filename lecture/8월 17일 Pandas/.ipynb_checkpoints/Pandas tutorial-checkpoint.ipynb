# %% [markdown]
# ## 예제로 판다스 풀어보기
#
# - 출처 : https://digital-play.tistory.com/64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 이번 노트에는 csv로 가져온다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Data를 불러올 때는 2가지 방법이 있다.
#     - 주피터 노트북과 같은 선상의 폴더에 csv 파일을 넣어놓고 read하는 방법.
#     - 해당 경로까지 작성해서 csv파일을 불러오는 방법.

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

# %% [markdown]
# ### 데이터 정보
# - Passengerid : 승객 번호
# - Survived : 생존 여부(0 = 사망, 1 = 생존)
# - Pclass : 티켓 종류(1 = 1st, 2 = 2nd, 3 = 3rd)
# - Name: 승객 이름
# - Sex: 승객 성별(male=남성, female=여성)
# - Age: 승객 나이
# - SibSp: 배우자나 형제자매의 총합
# - Parch: 부모 자식 명수의 총합
# - Ticket: 티켓 번호
# - Fare: 운임
# - Cabin: 객실 번호
# - Embarked: 승선 부두(C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# - index는 891 행 x 12 열 크기의 파일이다.

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 지정한 컬럼을 DataFrame의 index로 사용하는 방법

# %%
df = pd.read_csv("titanic.csv", index_col="PassengerId")

# %% [markdown]
# - 인덱스가 승객번호로 지정된 것을 확인 할 수 있다.

# %%
df.head().plot()
# Out:
# <AxesSubplot:>
